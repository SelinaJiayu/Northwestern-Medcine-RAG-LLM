# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd
from openpyxl import Workbook


def find_topics_url(base_url):
    response = requests.get(base_url)
    html_content = response.content

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find all div elements with class "col-sm-6"
    col_sm_6_divs = soup.find_all('div', class_='col-sm-6')

    # List to store the links
    links = []

    # Loop through each "col-sm-6" div to find anchor tags and extract their URLs
    for div in col_sm_6_divs:
        anchor_tag = div.find('a', href=True)
        if anchor_tag:
            href = anchor_tag['href']
            link_text = anchor_tag.get_text(strip=True)
            links.append((href, link_text))
    return links 


def process_siblings(heading, section_content):
    sibling = heading.find_next_sibling()
    while sibling:
        if sibling.name == 'ul':
            # Extract all list items from the unordered list
            li_elements = sibling.find_all('li')
            for li in li_elements:
                section_content['details'].append(li.get_text(strip=True))
        elif sibling.name == 'p':
            # Extract the paragraph text
            section_content['details'].append(sibling.get_text(strip=True))
        # elif sibling.name == "h3":
        #     section_content['details'].append(sibling.get_text(strip=True))
        #     section_content = process_siblings(sibling, section_content)
        elif sibling.name in ['h2', 'h3']:
            # Stop if we encounter another heading
            break
        sibling = sibling.find_next_sibling()
    return section_content

def scrape_content(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract all the headings (h2, h3) and corresponding <ul> lists and <p> tags below them
    content = []

    # Extract sections based on headings (h2, h3)
    headings = soup.find_all(['h2'])#, 'h3'])
    for heading in headings:
        title = heading.get_text(strip=True)
        section_content = {
            'title': title,
            'details': []
        }
        for sibling in heading.find_next_siblings():
            section_content['details'].append(sibling.get_text())
        # section_content = {
        #     'title': title,
        #     'details': []
        # }
        #section_content = process_siblings(heading, section_content)
        content.append(section_content)
    return content

def filter_extracted_data(data):
    final_data = []
    for entry in data: 
        if len(entry.get('details')) == 0:
            continue
        else:
            entry['details'] = '\n'.join(entry['details'])
        final_data.append(entry)
    return final_data

base_url = "https://www.radiologyinfo.org/en/onco"
topic_urls = find_topics_url(base_url)



final_df = pd.DataFrame(columns=["topic_name", "Question", "Answer"])

total = 0
for topic_url, _ in topic_urls:
    topic_name = topic_url.split('/')[-1]
    print(f"Topic Name : {topic_name} -- Topic Url : {topic_url}")
    extracted_data = scrape_content(topic_url)
    extracted_data = filter_extracted_data(extracted_data)

    topic_df = pd.DataFrame(extracted_data).rename({"title": "Question", "details" : "Answer"}, axis=1)
    topic_df['topic_name'] = [topic_name] * len(topic_df)
    topic_df = topic_df[['topic_name', 'Question', 'Answer']]
    total += topic_df.shape[0]
    final_df = pd.concat([final_df, topic_df])
# Out:
# Topic Name : anal-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/anal-cancer-therapy
# Topic Name : lung-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/lung-cancer-therapy
# Topic Name : brachy -- Topic Url : https://www.radiologyinfo.org/en/info/brachy
# Topic Name : lymphoma-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/lymphoma-cancer-therapy
# Topic Name : thera-brain -- Topic Url : https://www.radiologyinfo.org/en/info/thera-brain
# Topic Name : mri-guided-linac -- Topic Url : https://www.radiologyinfo.org/en/info/mri-guided-linac
# Topic Name : breast-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/breast-cancer-therapy
# Topic Name : pancreatic-cancer-treatment -- Topic Url : https://www.radiologyinfo.org/en/info/pancreatic-cancer-treatment
# Topic Name : cervical-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/cervical-cancer-therapy
# Topic Name : professions-radiation-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/professions-radiation-therapy
# Topic Name : colorect -- Topic Url : https://www.radiologyinfo.org/en/info/colorect
# Topic Name : pros_cancer -- Topic Url : https://www.radiologyinfo.org/en/info/pros_cancer
# Topic Name : esophageal-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/esophageal-cancer-therapy
# Topic Name : protonthera -- Topic Url : https://www.radiologyinfo.org/en/info/protonthera
# Topic Name : ebt -- Topic Url : https://www.radiologyinfo.org/en/info/ebt
# Topic Name : intro_onco -- Topic Url : https://www.radiologyinfo.org/en/info/intro_onco
# Topic Name : gamma_knife -- Topic Url : https://www.radiologyinfo.org/en/info/gamma_knife
# Topic Name : radiation-therapy-for-pain-relief -- Topic Url : https://www.radiologyinfo.org/en/info/radiation-therapy-for-pain-relief
# Topic Name : hdneck -- Topic Url : https://www.radiologyinfo.org/en/info/hdneck
# Topic Name : radioembol -- Topic Url : https://www.radiologyinfo.org/en/info/radioembol
# Topic Name : igrt -- Topic Url : https://www.radiologyinfo.org/en/info/igrt
# Topic Name : radio-immuno -- Topic Url : https://www.radiologyinfo.org/en/info/radio-immuno
# Topic Name : imrt -- Topic Url : https://www.radiologyinfo.org/en/info/imrt
# Topic Name : stereotactic -- Topic Url : https://www.radiologyinfo.org/en/info/stereotactic
# Topic Name : intracranialvasc -- Topic Url : https://www.radiologyinfo.org/en/info/intracranialvasc
# Topic Name : thermal-ablation-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/thermal-ablation-therapy
# Topic Name : linac -- Topic Url : https://www.radiologyinfo.org/en/info/linac
# Topic Name : thyroid-cancer-treatment -- Topic Url : https://www.radiologyinfo.org/en/info/thyroid-cancer-treatment
# Topic Name : anal-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/anal-cancer-therapy
# Topic Name : brachy -- Topic Url : https://www.radiologyinfo.org/en/info/brachy
# Topic Name : thera-brain -- Topic Url : https://www.radiologyinfo.org/en/info/thera-brain
# Topic Name : breast-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/breast-cancer-therapy
# Topic Name : cervical-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/cervical-cancer-therapy
# Topic Name : colorect -- Topic Url : https://www.radiologyinfo.org/en/info/colorect
# Topic Name : esophageal-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/esophageal-cancer-therapy
# Topic Name : ebt -- Topic Url : https://www.radiologyinfo.org/en/info/ebt
# Topic Name : gamma_knife -- Topic Url : https://www.radiologyinfo.org/en/info/gamma_knife
# Topic Name : hdneck -- Topic Url : https://www.radiologyinfo.org/en/info/hdneck
# Topic Name : igrt -- Topic Url : https://www.radiologyinfo.org/en/info/igrt
# Topic Name : imrt -- Topic Url : https://www.radiologyinfo.org/en/info/imrt
# Topic Name : intracranialvasc -- Topic Url : https://www.radiologyinfo.org/en/info/intracranialvasc
# Topic Name : linac -- Topic Url : https://www.radiologyinfo.org/en/info/linac
# Topic Name : lung-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/lung-cancer-therapy
# Topic Name : lymphoma-cancer-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/lymphoma-cancer-therapy
# Topic Name : mri-guided-linac -- Topic Url : https://www.radiologyinfo.org/en/info/mri-guided-linac
# Topic Name : pancreatic-cancer-treatment -- Topic Url : https://www.radiologyinfo.org/en/info/pancreatic-cancer-treatment
# Topic Name : professions-radiation-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/professions-radiation-therapy
# Topic Name : pros_cancer -- Topic Url : https://www.radiologyinfo.org/en/info/pros_cancer
# Topic Name : protonthera -- Topic Url : https://www.radiologyinfo.org/en/info/protonthera
# Topic Name : intro_onco -- Topic Url : https://www.radiologyinfo.org/en/info/intro_onco
# Topic Name : radiation-therapy-for-pain-relief -- Topic Url : https://www.radiologyinfo.org/en/info/radiation-therapy-for-pain-relief
# Topic Name : radioembol -- Topic Url : https://www.radiologyinfo.org/en/info/radioembol
# Topic Name : radio-immuno -- Topic Url : https://www.radiologyinfo.org/en/info/radio-immuno
# Topic Name : stereotactic -- Topic Url : https://www.radiologyinfo.org/en/info/stereotactic
# Topic Name : thermal-ablation-therapy -- Topic Url : https://www.radiologyinfo.org/en/info/thermal-ablation-therapy
# Topic Name : thyroid-cancer-treatment -- Topic Url : https://www.radiologyinfo.org/en/info/thyroid-cancer-treatment

# %%
print(final_df.iloc[1]['Answer'].strip())
# Out:
# Treatment options overview
# How can I choose from among the options?
# If I receive radiation therapy, will surgery still be required?
# How effective is modern radiation treatment of anal cancer?
#
#
# Treatment options overview
# Anal cancer is highly treatable when found early. Treatment options depend on the:
#
# type of cancer cell present
# stage of the cancer
# tumor location
# patient's human immunodeficiency virus (HIV) status
# recurrence of the cancer following treatment
# patient's preference and overall health
#
# There are three types of standard treatment for anal cancer:
#
# Radiation therapy—a cancer treatment that uses high-energy x-rays or other types of radiation to kill cancer cells. The type of radiation therapy used to treat anal cancer is:
#
# external beam therapy, in which high-energy x-ray beams generated by a machine are directed at the tumor from outside the body (usually by a linear accelerator) and targeted at the tumor site. These x-rays can destroy the cancer cells and careful treatment planning allows the surrounding normal tissues to be spared. No radioactive sources are placed inside the patient's body.
#
#
# Chemotherapy—a cancer treatment that uses chemical substances or drugs to kill cancer cells or stop them from dividing.
# Surgery—surgical treatments for anal cancer include:
#
# local resection, in which a small tumor in the lower part of the anus and some of the healthy tissue surrounding it are surgically removed.
# abdominoperineal resection, in which cancer cells in the anus, rectum and part of the large intestine are removed through an incision made in the abdomen. Lymph nodes that contain cancer may also be removed.
#
#
#
# How can I choose from among the options?
# The team of physicians responsible for your care will provide you with information specific to your care. Your physicians will recommend the appropriate treatment and discuss your options with you. Patients undergo a specific therapy because a cancer specialist, after analyzing all available data and the condition of the patient, has recommended it as the best way to treat the cancer. Generally, however, the majority of patients treated for anal cancer will be recommended a combination of radiation therapy and chemotherapy administered at the same time.
# If you are to undergo radiation therapy, a radiation oncologist will determine how much radiation is needed, to which areas of the body it should be delivered, and how many doses of radiation will be necessary.
# If I receive radiation therapy, will surgery still be required?
# The team of physicians responsible for your care will decide whether surgery would be recommended after completion of a course of radiation therapy. If surgery is recommended, the procedure performed is typically an abdominoperineal resection. Surgery is often recommended if your cancer does not completely respond to radiation therapy or if the cancer recurs in the anal canal after an initial period of treatment response.
# How effective is modern radiation treatment of anal cancer?
# Anal cancer is generally responsive to radiation therapy. Chemotherapy further improves upon the efficacy of radiation therapy. Recent improvements in radiation therapy also allow for improved sparing of normal tissues. Ultimately, however, the effectiveness of treatment is dependent on the stage of the cancer and your cancer's specific response to treatment.

# %%
#url = "https://www.radiologyinfo.org/en/info/esophageal-cancer-therapy"
url = "https://www.radiologyinfo.org/en/info/anal-cancer-therapy"
#anal-cancer-therapy
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

headings = soup.find_all(['h2'])
print(headings[0].get_text(strip=True))
for x in headings[0].find_next_siblings():
    print(x.get_text())
# Out:
# Anal cancer overview
# Anal cancer is a cancer that begins in the anus, the opening at the end of the gastrointestinal tract through which stool, or solid waste, leaves the body. The anus begins at the bottom of the rectum, which is the last part of the large intestine (also called the colon).
# Anal cancer usually affects adults over age 60 and women more often than men.

# %%
final_df.head(40)
# Out:
#                  topic_name  \
# 0       anal-cancer-therapy
# 1       anal-cancer-therapy
# 2       anal-cancer-therapy
# 3       anal-cancer-therapy
# 4       anal-cancer-therapy
# 5       anal-cancer-therapy
# 6       anal-cancer-therapy
# 7       anal-cancer-therapy
# 8       anal-cancer-therapy
# 9       anal-cancer-therapy
# 0       lung-cancer-therapy
# 1       lung-cancer-therapy
# 2       lung-cancer-therapy
# 3       lung-cancer-therapy
# 4       lung-cancer-therapy
# 5       lung-cancer-therapy
# 6       lung-cancer-therapy
# 7       lung-cancer-therapy
# 8       lung-cancer-therapy
# 9       lung-cancer-therapy
# 10      lung-cancer-therapy
# 11      lung-cancer-therapy
# 12      lung-cancer-therapy
# 13      lung-cancer-therapy
# 0                    brachy
# 1                    brachy
# 2                    brachy
# 3                    brachy
# 4                    brachy
# 5                    brachy
# 6                    brachy
# 7                    brachy
# 0   lymphoma-cancer-therapy
# 1   lymphoma-cancer-therapy
# 2   lymphoma-cancer-therapy
# 3   lymphoma-cancer-therapy
# 4   lymphoma-cancer-therapy
# 5   lymphoma-cancer-therapy
# 6   lymphoma-cancer-therapy
# 7   lymphoma-cancer-therapy
#
#                                              Question  \
# 0                                Anal cancer overview
# 1                          Treatment options overview
# 2            How can I choose from among the options?
# 3   If I receive radiation therapy, will surgery s...
# 4   How effective is modern radiation treatment of...
# 5              What happens during radiation therapy?
# 6   What are possible side effects of radiation th...
# 7   What kind of treatment follow-up should I expect?
# 8   Are there any new developments in treating my ...
# 9                                     Clinical Trials
# 0                                Lung cancer overview
# 1                            Pre-treatment evaluation
# 2                          Treatment options overview
# 3   How does the treatment method depend on the ty...
# 4   How does the stage of disease guide lung cance...
# 5   How effective is treatment for inoperable lung...
# 6              What happens during radiation therapy?
# 7   What are possible side effects of radiation th...
# 8   What kind of treatment follow-up should I expect?
# 9   Are there any new developments in treating my ...
# 10                                    Clinical Trials
# 11                                   Screening Trials
# 12                      New Screening Recommendations
# 13               Additional Information and Resources
# 0           What is brachytherapy and how is it used?
# 1             Who will be involved in this procedure?
# 2                             What equipment is used?
# 3                         Who operates the equipment?
# 4   Is there any special preparation needed for th...
# 5                     How is the procedure performed?
# 6             What will I feel during this procedure?
# 7                Additional Information and Resources
# 0                                    What is Lymphoma
# 1                          Treatment options overview
# 2            How can I choose from among the options?
# 3   How effective is modern radiation treatment of...
# 4              What happens during radiation therapy?
# 5   What are possible side effects of radiation th...
# 6   What kind of treatment follow-up should I expect?
# 7   Are there any new developments in treating my ...
#
#                                                Answer
# 0   Anal cancer is a cancer that begins in theanus...
# 1   Anal cancer is highly treatable when found ear...
# 2   The team of physicians responsible for your ca...
# 3   The team of physicians responsible for your ca...
# 4   Anal cancer is generally responsive to radiati...
# 5   Radiation therapy uses high energy x-rays (pho...
# 6   Side effects of radiation treatment include pr...
# 7   After your treatment has ended, your physician...
# 8   New treatments for anal cancer are being studi...
# 9   For information and resources about clinical t...
# 0   Lung cancer is a leading cause of cancer-relat...
# 1   Before treatment, the doctor will usually perf...
# 2   Tumor genomic testing is now standard of care ...
# 3   There are two main types of lung cancer that h...
# 4   Small-cell lung cancer:\nDoctors use chemother...
# 5   It is extremely important to remember that “in...
# 6   Radiation therapy delivers focused high-energy...
# 7   Overall, radiotherapy is a local treatment. An...
# 8   Once radiotherapy ends, your doctor will want ...
# 9   Less invasive surgical methods are under study...
# 10  For information and resources about clinical t...
# 11  ECOG-ACRIN Cancer Research Group\nNational Can...
# 12  American Society of Clinical Oncology\nNationa...
# 13  RTAnswers.org:Radiation Therapy for Lung Cance...
# 0   Brachytherapy, also calledinternal radiation t...
# 1   Brachytherapy requires a treatment team. This ...
# 2   The type of radioactive material used (iodine,...
# 3   The radiation oncologist creates the overall t...
# 4   Your doctor will tell you how to prepare for t...
# 5   Permanent brachytherapy:\nPermanent brachyther...
# 6   Before treatment begins, the doctor may place ...
# 7                         RTAnswers.org:Brachytherapy
# 0   Lymphoma is a cancer that develops in the whit...
# 1   Treatment depends on the type and stage of you...
# 2   Your doctors will provide you with information...
# 3   Radiation is extremely effective in treating l...
# 4   Radiation therapy uses high energy x-rays. Hig...
# 5   While side effects vary from person to person,...
# 6   Lymphoma can reappear (recur) in previously tr...
# 7   Contemporary therapy often cures lymphoma pati...

# %%
final_df[final_df.topic_name == "esophageal-cancer-therapy"]
# Out:
#                    topic_name  \
# 0   esophageal-cancer-therapy
# 1   esophageal-cancer-therapy
# 2   esophageal-cancer-therapy
# 3   esophageal-cancer-therapy
# 4   esophageal-cancer-therapy
# 5   esophageal-cancer-therapy
# 6   esophageal-cancer-therapy
# 7   esophageal-cancer-therapy
# 8   esophageal-cancer-therapy
# 9   esophageal-cancer-therapy
# 10  esophageal-cancer-therapy
# 0   esophageal-cancer-therapy
# 1   esophageal-cancer-therapy
# 2   esophageal-cancer-therapy
# 3   esophageal-cancer-therapy
# 4   esophageal-cancer-therapy
# 5   esophageal-cancer-therapy
# 6   esophageal-cancer-therapy
# 7   esophageal-cancer-therapy
# 8   esophageal-cancer-therapy
# 9   esophageal-cancer-therapy
# 10  esophageal-cancer-therapy
#
#                                              Question  \
# 0                          What is Esophageal Cancer?
# 1                      What are my treatment options?
# 2                                             Surgery
# 3                               Endoscopic Treatments
# 4                                        Chemotherapy
# 5   Monoclonal Antibody Therapy(also called target...
# 6                                       Immunotherapy
# 7                                   Radiation therapy
# 8              What happens during radiation therapy?
# 9   What are possible side effects of radiation th...
# 10  Are there any new developments in treating my ...
# 0                          What is Esophageal Cancer?
# 1                      What are my treatment options?
# 2                                             Surgery
# 3                               Endoscopic Treatments
# 4                                        Chemotherapy
# 5   Monoclonal Antibody Therapy(also called target...
# 6                                       Immunotherapy
# 7                                   Radiation therapy
# 8              What happens during radiation therapy?
# 9   What are possible side effects of radiation th...
# 10  Are there any new developments in treating my ...
#
#                                                Answer
# 0   Esophageal cancer develops in the lining of th...
# 1   Treatment options include:\nYour treatment pla...
# 2   Your doctor may use surgery alone for early-st...
# 3   Endoscopic treatments treat early and pre-canc...
# 4   This treatment stops cancer cells from dividin...
# 5   A small number of esophageal cancers have too ...
# 6   This treatment helps activate the body’s own i...
# 7   This treatment uses radiation to kill cancer c...
# 8   Before starting radiation therapy, patients wh...
# 9   Radiation treatment can cause side effects. Th...
# 10  New imaging methods, such as endoscopic ultras...
# 0   Esophageal cancer develops in the lining of th...
# 1   Treatment options include:\nYour treatment pla...
# 2   Your doctor may use surgery alone for early-st...
# 3   Endoscopic treatments treat early and pre-canc...
# 4   This treatment stops cancer cells from dividin...
# 5   A small number of esophageal cancers have too ...
# 6   This treatment helps activate the body’s own i...
# 7   This treatment uses radiation to kill cancer c...
# 8   Before starting radiation therapy, patients wh...
# 9   Radiation treatment can cause side effects. Th...
# 10  New imaging methods, such as endoscopic ultras...

# %%
import re

def extract_sub_questions_and_answers(text):
    # Split the text into lines
    lines = text.split('\n')
    
    questions_and_answers = []
    current_question = None
    current_answer = []
    
    # Treat the text before the first question as a separate Q&A
    first_line = lines[0].strip()
    first_question = first_line


    is_first = False
    # Iterate over each line to extract questions and answers
    for ind, line in enumerate(lines[1:]):
        # Remove extra whitespace and line breaks
        line = line.strip()

        # Check if the line is a question (ends with a question mark)
        if line.endswith('?'):
            if not is_first:
                is_first = True
                first_answer = "\n".join(lines[1:ind])
                questions_and_answers.append((first_question, first_answer))
            # If there is a current question, save the question and its answer
            if current_question:
                questions_and_answers.append((current_question, '\n'.join(current_answer)))
                current_answer = []

            # Set the new current question
            current_question = line
        else:
            # If it's not a question, it might be part of an answer
            if current_question:
                current_answer.append(line)

    # Add the last question-answer pair
    if current_question:
        questions_and_answers.append((current_question, ' '.join(current_answer)))

    return questions_and_answers

# %%
for line in final_df.iloc[1]['Answer'].split('\n'):
    if line.endswith('?'):
        print(line)
# Out:
# How can I choose from among the options?
# If I receive radiation therapy, will surgery still be required?
# How effective is modern radiation treatment of anal cancer?
# How effective is modern radiation treatment of anal cancer?
# If I receive radiation therapy, will surgery still be required?
# How effective is modern radiation treatment of anal cancer?
# How effective is modern radiation treatment of anal cancer?
# How can I choose from among the options?
# If I receive radiation therapy, will surgery still be required?
# How effective is modern radiation treatment of anal cancer?
# How effective is modern radiation treatment of anal cancer?
# If I receive radiation therapy, will surgery still be required?
# How effective is modern radiation treatment of anal cancer?
# How effective is modern radiation treatment of anal cancer?

# %%
final_rows = []
for idx,row in final_df.iterrows():
    # Check if the row has more questions
    if len(row['Answer'].split('?')) > 1:
        # Split the row into multiple rows
        qa = extract_sub_questions_and_answers(row['Answer'])
        sub_rows = []
        for item in qa:
            sub_rows.append({
                "topic_name" : row['topic_name'], 
                "Question" : item[0], 
                "Answer" : item[1]
            })
        final_rows.extend(sub_rows)
    else:
        final_rows.append({
            "topic_name" : row['topic_name'],
            "Question" : row['Question'], 
            "Answer" : row["Answer"]
        })

# %%
final_df.head()
# Out:
#             topic_name                                           Question  \
# 0  anal-cancer-therapy                               Anal cancer overview
# 1  anal-cancer-therapy                     What are my treatment options?
# 2  anal-cancer-therapy             What happens during radiation therapy?
# 3  anal-cancer-therapy  What are possible side effects of radiation th...
# 4  anal-cancer-therapy  What kind of treatment follow-up should I expect?
#
#                                               Answer
# 0  Anal cancer is a cancer that begins in theanus...
# 1  Treatment options overview\nAnal cancer is hig...
# 2  Radiation therapy uses high energy x-rays (pho...
# 3  Side effects of radiation treatment include pr...
# 4  After your treatment has ended, your physician...

# %%
final_df  = final_df[final_df.Question != "Send us your feedback"]
final_df.shape
# Out:
# (390, 3)

# %%
final_df = final_df[final_df.Question != "Additional Information and Resources"]
final_df.shape[0]
# Out:
# 368

# %%
import os 

os.makedirs("../data", exist_ok=True)
final_df.to_csv("../data/radiologyinfo-QA-extracted-uncleaned-v2.csv", index=False)
